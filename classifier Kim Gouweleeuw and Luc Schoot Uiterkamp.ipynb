# %%
import nltk
from nltk.corpus import reuters
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem.wordnet import WordNetLemmatizer
import string
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer

test = [reuters.raw(i) for i in reuters.fileids() if i[:4]=="test"]
test_y = [reuters.categories(i) for i in reuters.fileids() if i[:4]=="test"]
train = [reuters.raw(i) for i in reuters.fileids() if not i[:4]=="test"]
train_y = [reuters.categories(i) for i in reuters.fileids() if not i[:4]=="test"]
# Out:
# [['trade'],
#  ['grain'],
#  ['crude', 'nat-gas'],
#  ['corn', 'grain', 'rice', 'rubber', 'sugar', 'tin', 'trade'],
#  ['palm-oil', 'veg-oil'],
#  ['ship'],
#  ['coffee', 'lumber', 'palm-oil', 'rubber', 'veg-oil'],
#  ['grain', 'wheat'],
#  ['gold'],
#  ['acq'],
#  ['tin'],
#  ['interest', 'money-fx'],
#  ['acq', 'copper'],
#  ['ipi'],
#  ['carcass',
#   'corn',
#   'grain',
#   'livestock',
#   'oilseed',
#   'rice',
#   'soybean',
#   'trade'],
#  ['earn'],
#  ['earn'],
#  ['interest', 'money-fx'],
#  ['bop', 'trade'],
#  ['gas', 'lead'],
#  ['acq'],
#  ['jobs'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['tin'],
#  ['trade'],
#  ['zinc'],
#  ['sugar'],
#  ['sugar'],
#  ['acq'],
#  ['interest', 'money-fx'],
#  ['cpi', 'gnp'],
#  ['oilseed', 'palm-oil', 'soy-oil', 'soybean', 'veg-oil'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['trade'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['trade'],
#  ['dlr', 'money-fx', 'yen'],
#  ['cpi'],
#  ['interest', 'money-fx'],
#  ['acq'],
#  ['sugar'],
#  ['sugar'],
#  ['earn'],
#  ['nickel'],
#  ['earn'],
#  ['dlr', 'money-fx'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['acq'],
#  ['groundnut'],
#  ['earn'],
#  ['ship'],
#  ['earn'],
#  ['ship'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['interest', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['jobs'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['sugar'],
#  ['money-fx'],
#  ['sugar'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['sugar'],
#  ['earn'],
#  ['sugar'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['corn', 'grain'],
#  ['acq'],
#  ['heat'],
#  ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed', 'wheat'],
#  ['jobs'],
#  ['earn'],
#  ['money-fx'],
#  ['interest'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq', 'crude', 'earn', 'pet-chem'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['interest'],
#  ['earn'],
#  ['earn'],
#  ['cocoa'],
#  ['interest'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['corn', 'grain', 'oilseed', 'soybean'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['tin'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['oilseed', 'rapeseed'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['trade'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['trade'],
#  ['earn'],
#  ['earn'],
#  ['cocoa'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['coffee'],
#  ['crude'],
#  ['acq'],
#  ['earn'],
#  ['rice'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['dlr', 'interest', 'money-fx'],
#  ['earn'],
#  ['acq'],
#  ['tin'],
#  ['cotton'],
#  ['earn'],
#  ['earn'],
#  ['trade'],
#  ['earn'],
#  ['earn'],
#  ['crude'],
#  ['earn'],
#  ['money-fx'],
#  ['livestock'],
#  ['crude', 'earn'],
#  ['acq'],
#  ['earn'],
#  ['money-supply'],
#  ['earn'],
#  ['crude'],
#  ['money-supply'],
#  ['earn'],
#  ['earn'],
#  ['money-fx'],
#  ['carcass', 'livestock'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['iron-steel', 'trade'],
#  ['earn'],
#  ['copper'],
#  ['earn'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['corn', 'grain'],
#  ['l-cattle', 'livestock'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['grain'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['interest'],
#  ['acq'],
#  ['earn'],
#  ['iron-steel', 'trade'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['crude', 'nat-gas'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['coffee'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['crude', 'gas'],
#  ['corn', 'grain', 'veg-oil', 'wheat'],
#  ['crude', 'gas'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['crude', 'gas'],
#  ['trade'],
#  ['earn'],
#  ['earn'],
#  ['coffee'],
#  ['earn'],
#  ['acq'],
#  ['interest', 'money-fx'],
#  ['jobs'],
#  ['acq'],
#  ['grain', 'rice'],
#  ['alum'],
#  ['acq', 'trade'],
#  ['money-fx', 'trade'],
#  ['interest', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['interest'],
#  ['trade'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['sugar'],
#  ['earn'],
#  ['earn'],
#  ['yen'],
#  ['acq'],
#  ['earn'],
#  ['rubber'],
#  ['interest'],
#  ['gold'],
#  ['earn'],
#  ['sugar'],
#  ['nat-gas'],
#  ['earn'],
#  ['palladium', 'platinum', 'strategic-metal'],
#  ['acq'],
#  ['rubber'],
#  ['acq'],
#  ['earn'],
#  ['trade'],
#  ['earn'],
#  ['trade'],
#  ['dlr', 'money-fx'],
#  ['yen'],
#  ['interest', 'money-fx'],
#  ['earn'],
#  ['reserves'],
#  ['dlr', 'money-fx'],
#  ['interest', 'money-fx'],
#  ['sugar'],
#  ['trade'],
#  ['money-fx'],
#  ['dlr', 'money-fx'],
#  ['money-fx'],
#  ['earn'],
#  ['money-fx', 'trade'],
#  ['money-fx'],
#  ['yen'],
#  ['yen'],
#  ['earn'],
#  ['earn'],
#  ['dlr', 'money-fx'],
#  ['sugar'],
#  ['acq'],
#  ['acq'],
#  ['acq'],
#  ['gold'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['gold'],
#  ['earn'],
#  ['yen'],
#  ['ship'],
#  ['jobs'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['grain',
#   'groundnut-oil',
#   'lin-oil',
#   'meal-feed',
#   'oilseed',
#   'rape-oil',
#   'sorghum',
#   'soy-oil',
#   'sun-meal',
#   'sun-oil',
#   'veg-oil',
#   'wheat'],
#  ['acq'],
#  ['yen'],
#  ['livestock'],
#  ['money-fx'],
#  ['earn'],
#  ['earn'],
#  ['crude', 'heat'],
#  ['earn'],
#  ['interest', 'money-fx'],
#  ['money-fx'],
#  ['money-fx'],
#  ['earn'],
#  ['grain', 'ship'],
#  ['hog', 'livestock'],
#  ['earn'],
#  ['oilseed', 'soybean'],
#  ['interest', 'money-fx'],
#  ['coffee'],
#  ['acq'],
#  ['bop'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['dlr', 'yen'],
#  ['interest'],
#  ['gnp'],
#  ['interest', 'money-supply', 'trade'],
#  ['earn'],
#  ['lead'],
#  ['earn'],
#  ['earn'],
#  ['interest'],
#  ['acq'],
#  ['dlr'],
#  ['lead'],
#  ['acq'],
#  ['earn'],
#  ['grain', 'rice', 'sorghum', 'wheat'],
#  ['cotton'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['grain', 'wheat'],
#  ['bop'],
#  ['groundnut', 'oilseed'],
#  ['acq'],
#  ['interest'],
#  ['interest'],
#  ['grain'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['coffee'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['interest'],
#  ['acq'],
#  ['heat'],
#  ['interest'],
#  ['earn'],
#  ['interest', 'money-fx'],
#  ['acq'],
#  ['interest'],
#  ['barley', 'corn', 'grain', 'wheat'],
#  ['potato'],
#  ['money-fx'],
#  ['iron-steel'],
#  ['tin'],
#  ['dlr', 'money-fx'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['money-fx'],
#  ['earn'],
#  ['iron-steel'],
#  ['earn'],
#  ['earn'],
#  ['carcass', 'livestock'],
#  ['cotton'],
#  ['bop', 'trade'],
#  ['corn', 'grain'],
#  ['barley', 'grain'],
#  ['earn'],
#  ['cocoa'],
#  ['earn'],
#  ['money-fx'],
#  ['acq'],
#  ['trade'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['orange'],
#  ['barley', 'corn', 'grain', 'wheat'],
#  ['dlr', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['corn', 'grain', 'oilseed', 'soybean', 'wheat'],
#  ['earn'],
#  ['dlr', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['money-fx'],
#  ['earn'],
#  ['ship', 'sugar'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['grain', 'ship'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['corn', 'grain'],
#  ['oilseed', 'rapeseed'],
#  ['earn'],
#  ['coffee', 'trade'],
#  ['grain', 'ship'],
#  ['ship', 'sugar'],
#  ['barley', 'grain', 'ship', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['coffee', 'trade'],
#  ['acq'],
#  ['retail'],
#  ['earn'],
#  ['soy-oil', 'veg-oil'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['lead'],
#  ['reserves'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['bop'],
#  ['earn'],
#  ['carcass', 'livestock'],
#  ['earn'],
#  ['earn'],
#  ['gold'],
#  ['sugar'],
#  ['interest'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['gold'],
#  ['interest'],
#  ['tin'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['heat'],
#  ['copper'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['strategic-metal'],
#  ['trade'],
#  ['earn'],
#  ['grain'],
#  ['grain'],
#  ['corn', 'grain', 'oilseed', 'soybean', 'wheat'],
#  ['orange'],
#  ['orange'],
#  ['earn'],
#  ['earn'],
#  ['cotton',
#   'grain',
#   'meal-feed',
#   'oilseed',
#   'soy-meal',
#   'soy-oil',
#   'soybean',
#   'veg-oil',
#   'wheat'],
#  ['orange'],
#  ['orange'],
#  ['corn', 'grain'],
#  ['potato'],
#  ['potato'],
#  ['corn', 'grain', 'wheat'],
#  ['acq'],
#  ['corn', 'grain', 'wheat'],
#  ['grain', 'wheat'],
#  ['oilseed', 'soybean'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['grain', 'wheat'],
#  ['grain', 'wheat'],
#  ['grain', 'wheat'],
#  ['barley',
#   'corn',
#   'cotton',
#   'cotton-oil',
#   'grain',
#   'meal-feed',
#   'oat',
#   'oilseed',
#   'rice',
#   'sorghum',
#   'soy-meal',
#   'soy-oil',
#   'soybean',
#   'veg-oil'],
#  ['strategic-metal'],
#  ['grain', 'wheat'],
#  ['barley',
#   'corn',
#   'cotton',
#   'grain',
#   'meal-feed',
#   'oat',
#   'oilseed',
#   'rice',
#   'sorghum',
#   'soy-meal',
#   'soy-oil',
#   'soybean',
#   'veg-oil',
#   'wheat'],
#  ['cotton'],
#  ['corn', 'grain'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['corn',
#   'cotton',
#   'grain',
#   'meal-feed',
#   'oilseed',
#   'soy-meal',
#   'soy-oil',
#   'soybean',
#   'veg-oil',
#   'wheat'],
#  ['acq'],
#  ['grain', 'wheat'],
#  ['acq'],
#  ['grain', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['meal-feed', 'soy-meal'],
#  ['corn', 'grain'],
#  ['corn',
#   'cotton',
#   'grain',
#   'meal-feed',
#   'oilseed',
#   'rice',
#   'soy-meal',
#   'soy-oil',
#   'soybean',
#   'veg-oil',
#   'wheat'],
#  ['earn'],
#  ['earn'],
#  ['corn', 'grain'],
#  ['corn', 'grain', 'meal-feed', 'soy-meal', 'wheat'],
#  ['acq'],
#  ['earn'],
#  ['grain'],
#  ['grain', 'wheat'],
#  ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed', 'wheat'],
#  ['acq'],
#  ['acq'],
#  ['oilseed', 'soybean'],
#  ['meal-feed', 'soy-meal'],
#  ['soy-oil', 'veg-oil'],
#  ['fuel'],
#  ['cotton'],
#  ['grain', 'wheat'],
#  ['grain', 'rice'],
#  ['orange'],
#  ['earn'],
#  ['copper'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['crude'],
#  ['grain', 'ship'],
#  ['earn'],
#  ['livestock'],
#  ['money-supply'],
#  ['money-supply'],
#  ['barley', 'corn', 'grain', 'oat', 'sorghum', 'wheat'],
#  ['meal-feed', 'oilseed', 'soy-meal', 'soybean'],
#  ['acq'],
#  ['earn'],
#  ['orange'],
#  ['acq'],
#  ['acq'],
#  ['crude'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['cotton'],
#  ['grain', 'meal-feed', 'oilseed', 'veg-oil'],
#  ['money-supply'],
#  ['money-supply'],
#  ['money-supply'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['money-supply'],
#  ['copper'],
#  ['money-supply'],
#  ['acq'],
#  ['acq'],
#  ['money-supply'],
#  ['acq'],
#  ['corn', 'grain', 'oilseed', 'soybean'],
#  ['acq'],
#  ['earn'],
#  ['money-fx'],
#  ['crude'],
#  ['money-fx'],
#  ['acq', 'crude', 'nat-gas'],
#  ['cotton', 'gold', 'grain', 'livestock', 'money-fx', 'silver'],
#  ['corn', 'grain'],
#  ['earn'],
#  ['grain', 'ship'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['crude', 'ship'],
#  ['acq'],
#  ['earn'],
#  ['trade'],
#  ['dlr', 'interest', 'money-fx'],
#  ['earn'],
#  ['money-supply'],
#  ['dlr', 'money-fx'],
#  ['dlr', 'money-fx'],
#  ['dlr', 'money-fx'],
#  ['dlr', 'money-fx'],
#  ['corn', 'grain', 'oat', 'sorghum', 'wheat'],
#  ['interest', 'money-fx'],
#  ['interest'],
#  ['interest'],
#  ['ship'],
#  ['crude'],
#  ['grain', 'rice'],
#  ['rape-oil', 'soy-oil', 'veg-oil'],
#  ['interest', 'money-supply'],
#  ['earn'],
#  ['trade'],
#  ['acq'],
#  ['sugar'],
#  ['trade'],
#  ['trade'],
#  ['interest'],
#  ['coffee'],
#  ['cocoa'],
#  ['corn', 'grain', 'rice'],
#  ['jobs'],
#  ['cpi'],
#  ['dlr', 'money-fx'],
#  ['cotton'],
#  ['bop', 'cpi', 'gnp'],
#  ['copper'],
#  ['dlr', 'money-fx'],
#  ['earn'],
#  ['coffee'],
#  ['acq'],
#  ['cpi', 'income', 'retail', 'trade', 'wpi'],
#  ['earn'],
#  ['interest'],
#  ['iron-steel'],
#  ['copper'],
#  ['trade'],
#  ['trade'],
#  ['acq'],
#  ['money-fx'],
#  ['cpi'],
#  ['acq'],
#  ['trade'],
#  ['earn'],
#  ['earn'],
#  ['ipi'],
#  ['money-fx'],
#  ['grain', 'wheat'],
#  ['acq'],
#  ['meal-feed'],
#  ['corn', 'grain', 'groundnut', 'oilseed', 'rice'],
#  ['cocoa'],
#  ['gold'],
#  ['interest'],
#  ['acq'],
#  ['acq'],
#  ['bop', 'cpi', 'gnp', 'jobs'],
#  ['acq'],
#  ['interest', 'money-fx'],
#  ['gold', 'platinum'],
#  ['acq'],
#  ['wpi'],
#  ['nat-gas'],
#  ['earn'],
#  ['gnp'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['money-fx'],
#  ['alum'],
#  ['interest', 'money-fx'],
#  ['sugar'],
#  ['money-fx'],
#  ['dlr', 'money-fx'],
#  ['money-fx', 'trade'],
#  ['palm-oil', 'veg-oil'],
#  ['zinc'],
#  ['wpi'],
#  ['gnp'],
#  ['gnp'],
#  ['dlr'],
#  ['gnp'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['gold'],
#  ['money-fx'],
#  ['interest'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['tea'],
#  ['bop', 'cpi', 'gnp'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['livestock'],
#  ['nat-gas'],
#  ['cpi'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['gold', 'platinum', 'silver'],
#  ['money-supply', 'reserves'],
#  ['money-fx'],
#  ['earn'],
#  ['hog', 'livestock'],
#  ['trade'],
#  ['trade'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['grain', 'meal-feed', 'oilseed'],
#  ['earn'],
#  ['cpi', 'gnp', 'money-supply'],
#  ['earn'],
#  ['wpi'],
#  ['grain', 'wheat'],
#  ['interest'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['coffee'],
#  ['lei'],
#  ['money-supply'],
#  ['earn'],
#  ['earn'],
#  ['money-fx'],
#  ['gold'],
#  ['acq'],
#  ['earn'],
#  ['lead'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['interest'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['interest'],
#  ['acq'],
#  ['lei'],
#  ['earn'],
#  ['earn'],
#  ['fuel'],
#  ['earn'],
#  ['livestock'],
#  ['earn'],
#  ['alum'],
#  ['earn'],
#  ['acq', 'alum'],
#  ['earn'],
#  ['sugar'],
#  ['money-fx'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['trade'],
#  ['grain'],
#  ['earn'],
#  ['palm-oil', 'veg-oil'],
#  ['earn'],
#  ['earn'],
#  ['crude', 'ship'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq', 'carcass', 'livestock'],
#  ['earn'],
#  ['interest', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq', 'earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['interest'],
#  ['acq'],
#  ['earn'],
#  ['cpi'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['crude'],
#  ['earn'],
#  ['earn'],
#  ['oilseed', 'rapeseed'],
#  ['earn'],
#  ['earn'],
#  ['crude', 'nat-gas'],
#  ['earn'],
#  ['earn'],
#  ['trade'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['acq', 'earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['nat-gas'],
#  ['earn'],
#  ['trade'],
#  ['acq'],
#  ['acq'],
#  ['acq'],
#  ['earn'],
#  ['acq', 'livestock'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['corn', 'grain', 'oilseed', 'soybean', 'wheat'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['carcass', 'livestock'],
#  ['interest', 'money-fx'],
#  ['earn'],
#  ['earn'],
#  ['acq'],
#  ['earn'],
#  ['acq'],
#  ['gas'],
#  ['acq'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['earn'],
#  ['gold'],
#  ['earn'],
#  ['acq'],
#  ...]

# %%
# preprocessing 1


def removePunctuation(text):
    return text.translate(str.maketrans('','',string.punctuation))
    
def tokenize(text):
    text = text.lower()
    return nltk.word_tokenize(text)

def removeStopwords(text):
    return [word for word in text if word not in stopwords.words('english')]

def stemmer(text):
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in text]

def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(word) for word in text]

def goodProcessing(text):
    processedText = []
    for i in text:
        tokenizedText = removePunctuation(i) 
        tokenizedText = tokenize(tokenizedText)
        tokenizedText = removeStopwords(tokenizedText)
        tokenizedText = lemmatize(tokenizedText)
        processedText.append(tokenizedText)

    return processedText

def badProcessing(text):
    processedText = []
    for i in text:
        tokenizedText = removePunctuation(i)
        tokenizedText = tokenize(tokenizedText)
        tokenizedText = stemmer(tokenizedText)
        processedText.append(tokenizedText)
    return processedText
# Out:
# 3019

# %%
# vect.fit(train)
# print(train[0])
# X_train_dtm = vect.transform(train)
# print(X_train_dtm[0])
# X_test_dtm = vect.transform(test)

xTrain = goodProcessing(train)
xTest = goodProcessing(test)

# %%
nb = MultinomialNB()

y_test_pred = nb.fit(xTrain, train_y).predict(xTest)


# metrics.accuracy_score(test_y, y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4288730a2752> in <module>
#       1 nb = MultinomialNB()
#       2
# ----> 3 y_test_pred = nb.fit(xTrain, train_y).predict(xTest)
#       4
#       5
#
# c:\python37\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     607         self : object
#     608         """
# --> 609         X, y = self._check_X_y(X, y)
#     610         _, n_features = X.shape
#     611         self.n_features_ = n_features
#
# c:\python37\lib\site-packages\sklearn\naive_bayes.py in _check_X_y(self, X, y)
#     473
#     474     def _check_X_y(self, X, y):
# --> 475         return check_X_y(X, y, accept_sparse='csr')
#     476
#     477     def _update_class_log_prior(self, class_prior=None):
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[list(['bahia', 'cocoa', 'review', 'shower', 'continued', 'throughout', 'week', 'bahia', 'cocoa', 'zone', 'alleviating', 'drought', 'since', 'early', 'january', 'improving', 'prospect', 'coming', 'temporao', 'although', 'normal', 'humidity', 'level', 'restored', 'comissaria', 'smith', 'said', 'weekly', 'review', 'dry', 'period', 'mean', 'temporao', 'late', 'year', 'arrival', 'week', 'ended', 'february', '22', '155221', 'bag', '60', 'kilo', 'making', 'cumulative', 'total', 'season', '593', 'mln', '581', 'stage', 'last', 'year', 'seems', 'cocoa', 'delivered', 'earlier', 'consignment', 'included', 'arrival', 'figure', 'comissaria', 'smith', 'said', 'still', 'doubt', 'much', 'old', 'crop', 'cocoa', 'still', 'available', 'harvesting', 'practically', 'come', 'end', 'total', 'bahia', 'crop', 'estimate', 'around', '64', 'mln', 'bag', 'sale', 'standing', 'almost', '62', 'mln', 'hundred', 'thousand', 'bag', 'still', 'hand', 'farmer', 'middleman', 'exporter', 'processor', 'doubt', 'much', 'cocoa', 'would', 'fit', 'export', 'shipper', 'experiencing', 'dificulties', 'obtaining', 'bahia', 'superior', 'certificate', 'view', 'lower', 'quality', 'recent', 'week', 'farmer', 'sold', 'good', 'part', 'cocoa', 'held', 'consignment', 'comissaria', 'smith', 'said', 'spot', 'bean', 'price', 'rose', '340', '350', 'cruzados', 'per', 'arroba', '15', 'kilo', 'bean', 'shipper', 'reluctant', 'offer', 'nearby', 'shipment', 'limited', 'sale', 'booked', 'march', 'shipment', '1750', '1780', 'dlrs', 'per', 'tonne', 'port', 'named', 'new', 'crop', 'sale', 'also', 'light', 'open', 'port', 'junejuly', 'going', '1850', '1880', 'dlrs', '35', '45', 'dlrs', 'new', 'york', 'july', 'augsept', '1870', '1875', '1880', 'dlrs', 'per', 'tonne', 'fob', 'routine', 'sale', 'butter', 'made', 'marchapril', 'sold', '4340', '4345', '4350', 'dlrs', 'aprilmay', 'butter', 'went', '227', 'time', 'new', 'york', 'may', 'junejuly', '4400', '4415', 'dlrs', 'augsept', '4351', '4450', 'dlrs', '227', '228', 'time', 'new', 'york', 'sept', 'octdec', '4480', 'dlrs', '227', 'time', 'new', 'york', 'dec', 'comissaria', 'smith', 'said', 'destination', 'u', 'covertible', 'currency', 'area', 'uruguay', 'open', 'port', 'cake', 'sale', 'registered', '785', '995', 'dlrs', 'marchapril', '785', 'dlrs', 'may', '753', 'dlrs', 'aug', '039', 'time', 'new', 'york', 'dec', 'octdec', 'buyer', 'u', 'argentina', 'uruguay', 'convertible', 'currency', 'area', 'liquor', 'sale', 'limited', 'marchapril', 'selling', '2325', '2380', 'dlrs', 'junejuly', '2375', 'dlrs', '125', 'time', 'new', 'york', 'july', 'augsept', '2400', 'dlrs', '125', 'time', 'new', 'york', 'sept', 'octdec', '125', 'time', 'new', 'york', 'dec', 'comissaria', 'smith', 'said', 'total', 'bahia', 'sale', 'currently', 'estimated', '613', 'mln', 'bag', '198687', 'crop', '106', 'mln', 'bag', '198788', 'crop', 'final', 'figure', 'period', 'february', '28', 'expected', 'published', 'brazilian', 'cocoa', 'trade', 'commission', 'carnival', 'end', 'midday', 'february', '27'])
#  list(['computer', 'terminal', 'system', 'ltcpml', 'completes', 'sale', 'computer', 'terminal', 'system', 'inc', 'said', 'completed', 'sale', '200000', 'share', 'common', 'stock', 'warrant', 'acquire', 'additional', 'one', 'mln', 'share', 'ltsedio', 'nv', 'lugano', 'switzerland', '50000', 'dlrs', 'company', 'said', 'warrant', 'exercisable', 'five', 'year', 'purchase', 'price', '125', 'dlrs', 'per', 'share', 'computer', 'terminal', 'said', 'sedio', 'also', 'right', 'buy', 'additional', 'share', 'increase', 'total', 'holding', '40', 'pct', 'computer', 'terminal', 'outstanding', 'common', 'stock', 'certain', 'circumstance', 'involving', 'change', 'control', 'company', 'company', 'said', 'condition', 'occur', 'warrant', 'would', 'exercisable', 'price', 'equal', '75', 'pct', 'common', 'stock', 'market', 'price', 'time', 'exceed', '150', 'dlrs', 'per', 'share', 'computer', 'terminal', 'also', 'said', 'sold', 'technolgy', 'right', 'dot', 'matrix', 'impact', 'technology', 'including', 'future', 'improvement', 'ltwoodco', 'inc', 'houston', 'tex', '200000', 'dlrs', 'said', 'would', 'continue', 'exclusive', 'worldwide', 'licensee', 'technology', 'woodco', 'company', 'said', 'move', 'part', 'reorganization', 'plan', 'would', 'help', 'pay', 'current', 'operation', 'cost', 'ensure', 'product', 'delivery', 'computer', 'terminal', 'make', 'computer', 'generated', 'label', 'form', 'tag', 'ticket', 'printer', 'terminal'])
#  list(['nz', 'trading', 'bank', 'deposit', 'growth', 'rise', 'slightly', 'new', 'zealand', 'trading', 'bank', 'seasonally', 'adjusted', 'deposit', 'growth', 'rose', '26', 'pct', 'january', 'compared', 'rise', '94', 'pct', 'december', 'reserve', 'bank', 'said', 'yearonyear', 'total', 'deposit', 'rose', '306', 'pct', 'compared', '263', 'pct', 'increase', 'december', 'year', '345', 'pct', 'rise', 'year', 'ago', 'period', 'said', 'weekly', 'statistical', 'release', 'total', 'deposit', 'rose', '1718', 'billion', 'nz', 'dlrs', 'january', 'compared', '1674', 'billion', 'december', '1316', 'billion', 'january', '1986'])
#  ...
#  list(['technitrol', 'inc', 'lttnl', 'set', 'quarterly', 'qtly', 'div', '12', 'ct', 'v', '12', 'ct', 'prior', 'pay', 'april', '21', 'record', 'april', 'seven'])
#  list(['nationwide', 'cellular', 'service', 'inc', 'ltncel', '4th', 'qtr', 'shr', 'loss', 'six', 'ct', 'v', 'loss', '18', 'ct', 'net', 'loss', '89478', 'v', 'loss', '178507', 'rev', '3894844', 'v', '1964141', 'avg', 'shrs', '1582790', 'v', 'one', 'mln', 'year', 'shr', 'loss', '43', 'ct', 'v', 'loss', '81', 'ct', 'net', 'loss', '534099', 'v', 'loss', '811836', 'rev', '122', 'mln', 'v', '5167573', 'avg', 'shrs', '1251337', 'v', 'one', 'mln'])
#  list(['ltaha', 'automotive', 'technology', 'corp', 'year', 'net', 'shr', '43', 'ct', 'v', '52', 'ct', 'shr', 'diluted', '41', 'ct', 'v', '49', 'ct', 'net', '1916000', 'v', '2281000', 'rev', '326', 'mln', 'v', '226', 'mln'])].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
